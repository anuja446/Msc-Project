# %% [markdown]
# import libaries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# import csv file

# %%
online_edu=pd.read_csv("online_edu.csv")
online_edu
# Out:
#                           Timestamp             Name  \
# 0    2021/03/07 7:27:13 PM GMT+5:30              NaN
# 1    2021/03/07 9:53:26 PM GMT+5:30            Geeta
# 2   2021/03/07 10:00:49 PM GMT+5:30            Swati
# 3   2021/03/07 10:12:39 PM GMT+5:30             Tanu
# 4    2021/03/08 5:25:58 PM GMT+5:30  Manasvi Sharma
# ..                              ...              ...
# 82  2021/03/29 10:53:14 PM GMT+5:30            Ayush
# 83  2021/03/29 10:54:21 PM GMT+5:30           Akshay
# 84  2021/04/02 12:05:43 PM GMT+5:30          Jigisha
# 85  2021/04/02 12:06:54 PM GMT+5:30             Ritu
# 86   2021/04/02 9:33:39 PM GMT+5:30           Shruti
#
#        Education Qualification Which device do you use for online learning?  \
# 0              Post-Graduation                                   Smartphone
# 1   Higher secondary (11-12th)                                       Laptop
# 2           Graduation/Diploma                                       Laptop
# ...

# %% [markdown]
# Display the number of rows and columns

# %%
online_edu.shape
# Out:
# (87, 21)

# %% [markdown]
# Display the types of data

# %%
online_edu.dtypes
# Out:
# Timestamp                                                                      object
# Name                                                                           object
# Education Qualification                                                        object
# Which device do you use for online learning?                                   object
# Which app do you use for online lectures?                                      object
# Do you have a proper internet connection?                                      object
# How much time on an average do you spend on online lectures?                   object
# Are you able to have proper audio/video during lectures?                       object
# Are you satisfied with the technology and software that you use?               object
# Do you have proper communication with your teachers during online learning?    object
# Do you mind asking questions when you have any doubt/problem?                  object
# ...

# %% [markdown]
# info of data

# %%
online_edu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 21 columns):
#  #   Column                                                                       Non-Null Count  Dtype
# ---  ------                                                                       --------------  -----
#  0   Timestamp                                                                    87 non-null     object
#  1   Name                                                                         86 non-null     object
#  2   Education Qualification                                                      87 non-null     object
#  3   Which device do you use for online learning?                                 87 non-null     object
#  4   Which app do you use for online lectures?                                    87 non-null     object
#  5   Do you have a proper internet connection?                                    87 non-null     object
# ...

# %% [markdown]
# Display top 5 Records

# %%
online_edu.head()
# Out:
#                          Timestamp             Name  \
# 0   2021/03/07 7:27:13 PM GMT+5:30              NaN
# 1   2021/03/07 9:53:26 PM GMT+5:30            Geeta
# 2  2021/03/07 10:00:49 PM GMT+5:30            Swati
# 3  2021/03/07 10:12:39 PM GMT+5:30             Tanu
# 4   2021/03/08 5:25:58 PM GMT+5:30  Manasvi Sharma
#
#       Education Qualification Which device do you use for online learning?  \
# 0             Post-Graduation                                   Smartphone
# 1  Higher secondary (11-12th)                                       Laptop
# 2          Graduation/Diploma                                       Laptop
# 3                   Secondary                                      Desktop
# 4             Post-Graduation                                      Desktop
#
#   Which app do you use for online lectures?  \
# 0                           Microsoft teams
# 1                               Google Meet
# 2                               Google Meet
# ...

# %% [markdown]
# Display last 5 records

# %%
online_edu.tail()
# Out:
#                           Timestamp     Name     Education Qualification  \
# 82  2021/03/29 10:53:14 PM GMT+5:30    Ayush  Higher secondary (11-12th)
# 83  2021/03/29 10:54:21 PM GMT+5:30   Akshay  Higher secondary (11-12th)
# 84  2021/04/02 12:05:43 PM GMT+5:30  Jigisha             Post-Graduation
# 85  2021/04/02 12:06:54 PM GMT+5:30     Ritu               PhD and other
# 86   2021/04/02 9:33:39 PM GMT+5:30   Shruti  Higher secondary (11-12th)
#
#    Which device do you use for online learning?  \
# 82                                   Smartphone
# 83                                      Desktop
# 84                                       Laptop
# 85                                   Smartphone
# 86                                      Desktop
#
#    Which app do you use for online lectures?  \
# 82                                      Zoom
# 83                               Google Meet
# 84                                      Zoom
# 85                               Google Meet
# ...

# %%
online_edu.describe()
# Out:
#        Rate your overall online learning experience from 1-5, 5 being the best
# count                                          87.000000
# mean                                            3.252874
# std                                             0.865601
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
